# %% [markdown]
# # CT206/109483/22
# # Christopher Mbuthia
# # BCSF 4.1
#
# # CDS 3252: Data Analytics and Visualization
#
# # Assignment 1:
# ---

# %% [markdown]
# **This notebook shows simple dataset manipulation using pandas to perform basic data cleaning and simple visualization using matplotlib**.
#
# **I will be using a labeled network traffic dataset used to detect and classify cyberattacks versus normal activity in intrusion detection research.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load the dataset using pandas

# %%
df=pd.read_csv('UNSW_NB15_training-set.csv')

# %% [markdown]
# **Get Basic structure of the dataset such as dimensions, columns and summary stats**

# %%
df.head()
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0   1  0.000011   udp       -   INT      2      0     496       0
# 1   2  0.000008   udp       -   INT      2      0    1762       0
# 2   3  0.000005   udp       -   INT      2      0    1068       0
# 3   4  0.000006   udp       -   INT      2      0     900       0
# 4   5  0.000010   udp       -   INT      2      0    2126       0
#
#           rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0   90909.0902  ...                 1               2             0
# 1  125000.0003  ...                 1               2             0
# 2  200000.0051  ...                 1               3             0
# 3  166666.6608  ...                 1               3             0
# 4  100000.0025  ...                 1               3             0
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0           0                 0           1           2                0
# ...

# %%
df.shape
# Out:
# (82332, 45)

# %% [markdown]
# Descriptive statistics for numeric columns

# %%
df.describe()
# Out:
#                  id           dur         spkts         dpkts        sbytes  \
# count  82332.000000  82332.000000  82332.000000  82332.000000  8.233200e+04
# mean   41166.500000      1.006756     18.666472     17.545936  7.993908e+03
# std    23767.345519      4.710444    133.916353    115.574086  1.716423e+05
# min        1.000000      0.000000      1.000000      0.000000  2.400000e+01
# 25%    20583.750000      0.000008      2.000000      0.000000  1.140000e+02
# 50%    41166.500000      0.014138      6.000000      2.000000  5.340000e+02
# 75%    61749.250000      0.719360     12.000000     10.000000  1.280000e+03
# max    82332.000000     59.999989  10646.000000  11018.000000  1.435577e+07
#
#              dbytes          rate          sttl          dttl         sload  \
# count  8.233200e+04  8.233200e+04  82332.000000  82332.000000  8.233200e+04
# mean   1.323379e+04  8.241089e+04    180.967667     95.713003  6.454902e+07
# ...

# %% [markdown]
# List the columns in the datasets

# %%
df.columns
# Out:
# Index(['id', 'dur', 'proto', 'service', 'state', 'spkts', 'dpkts', 'sbytes',
#        'dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss',
#        'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin',
#        'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth',
#        'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm',
#        'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm',
#        'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm',
#        'ct_srv_dst', 'is_sm_ips_ports', 'attack_cat', 'label'],
#       dtype='object')

# %% [markdown]
# # Basic Data Cleaning

# %% [markdown]
# Checking for null values per column

# %%
df.isnull().sum()
# Out:
# id                   0
# dur                  0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ...

# %% [markdown]
# **Drop null values**

# %%
df_clean=df.dropna()
df_clean
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0          1  0.000011   udp       -   INT      2      0     496       0
# 1          2  0.000008   udp       -   INT      2      0    1762       0
# 2          3  0.000005   udp       -   INT      2      0    1068       0
# 3          4  0.000006   udp       -   INT      2      0     900       0
# 4          5  0.000010   udp       -   INT      2      0    2126       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 82327  82328  0.000005   udp       -   INT      2      0     104       0
# 82328  82329  1.106101   tcp       -   FIN     20      8   18062     354
# 82329  82330  0.000000   arp       -   INT      1      0      46       0
# 82330  82331  0.000000   arp       -   INT      1      0      46       0
# 82331  82332  0.000009   udp       -   INT      2      0     104       0
#
#                 rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# ...

# %% [markdown]
# Remove Duplicates

# %%
duplicates=df_clean.duplicated().sum()
df_clean=df_clean.drop_duplicates()

# %% [markdown]
# Display final shape after cleaning

# %%
df_clean.shape
# Out:
# (82332, 45)

# %% [markdown]
# # Simple Visualization using **Matplotlib** and **Seaborn**

# %% [markdown]
# **Bar chart showing Attack category distribution**

# %%
plt.figure(figsize=(10,5))
cat_order=df_clean["attack_cat"].value_counts().index
sns.countplot(data=df_clean, x="attack_cat", order=cat_order)

plt.title("Attack Category Distribution")
plt.xlabel("Attack Category")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Piechart showing ratio between normal and attack traffic.

# %%
labels = ['Normal', 'Attack']
sizes = df_clean['label'].value_counts().sort_index()
colors = ['lightgreen', 'salmon']

plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=90)
plt.title("Normal vs Attack Traffic Ratio")
plt.show()

# %% [markdown]
# # Histogram showing Distribution of packet rate

# %%
plt.figure(figsize=(8,5))
plt.hist(df_clean['rate'], bins=40, color='steelblue', edgecolor='black')
plt.title("Distribution of Packet Rate")
plt.xlabel("Rate")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Scatter plot visualizing relationship between connection duration and data size.

# %%
plt.figure(figsize=(8,5))
plt.scatter(df_clean['dur'], df['sbytes'], alpha=0.3, color='orange')
plt.title("Duration vs Source Bytes")
plt.xlabel("Duration")
plt.ylabel("Source Bytes")
plt.show()

# %% [markdown]
# # A Heatmap showing the proportion of different attack types across various network services

# %%
plt.figure(figsize=(14, 10))
service_attack_normalized = pd.crosstab(df_clean['service'], df_clean['attack_cat'], normalize='index')
sns.heatmap(service_attack_normalized, 
            annot=True, 
            fmt='.2f',           # Format as 2 decimal places
            cmap='Reds',        # Red color scheme for proportions
            cbar=True,
            linewidths=0.5)

plt.title('Service vs Attack Category Heatmap (Normalized by Service)', fontsize=16, fontweight='bold')
plt.xlabel('Attack Category', fontsize=12)
plt.ylabel('Service', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
